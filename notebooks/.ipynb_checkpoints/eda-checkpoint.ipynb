# %%
import pandas as pd

# %%
df = pd.read_csv('../data/Training Log - 2023.csv')

df = df.iloc[2:5]
df.columns = df.iloc[0]
df = df.iloc[1:3]
df = df.set_index(df.columns[0])
df.columns.name = None
df = df.transpose()
df['RH'] = df['RH'].astype(int)
df['LH'] = df['LH'].astype(int)

# %%
df.plot()
# Out:
# <Axes: >
